# %% [markdown]
# # Animal Shelter Pt. 2 - Adoption Rate Prediction
# - In Part 1, the dependent variable was "Outcome Type", meaning the model predicts whether an animal will face a positive (adopted, returned to owner, transfer) or negative (euthanize, dead, disposed, stolen) outcome.
#
#
# - In this section, the dependent variable is "days in shelter"
#     - How long will an animal stay at the shelter?
#     - How can the shelter increase a given animal's appeal to increase adoption rate?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
from scipy import stats
from pylab import savefig

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from collections import Counter

plt.style.use('ggplot')

import warnings
warnings.filterwarnings("ignore")

#show all columns
pd.set_option('display.max_columns', None)

# %%
#import csv into a pandas dataframe
df = pd.read_csv('data/Animal_Shelter_Intake_and_Outcome.csv')

# %%
#how much of the data are NaN's?
df.isna().sum()/len(df)
# Out:
# Name                    0.256197
# Type                    0.000000
# Breed                   0.000000
# Color                   0.000000
# Sex                     0.000000
# Size                    0.001552
# Date Of Birth           0.241324
# Impound Number          0.000000
# Kennel Number           0.000401
# Animal ID               0.000000
# Intake Date             0.000000
# Outcome Date            0.004407
# Days in Shelter         0.000000
# Intake Type             0.000000
# Intake Subtype          0.000000
# Outcome Type            0.004657
# Outcome Subtype         0.014272
# Intake Condition        0.000000
# Outcome Condition       0.015674
# Intake Jurisdiction     0.000000
# Outcome Jurisdiction    0.139516
# Outcome Zip Code        0.141069
# Location                0.141069
# Count                   0.000000
# dtype: float64

# %%
df.groupby('Outcome Type').count()['Animal ID'].plot(kind='bar', figsize=(8,5))
df.groupby('Outcome Type').count()['Animal ID']
# Out:
# Outcome Type
# ADOPTION           6326
# DIED                135
# DISPOSAL            125
# ESCAPED/STOLEN       17
# EUTHANIZE          2779
# RETURN TO OWNER    6711
# RTOS                 11
# TRANSFER           3772
# Name: Animal ID, dtype: int64

# %%
#datetime_type = year, month, dayofweek, or hour
def parse_date_cols(df, col: str, new_col: str, datetime_type: str):
    df[col] = pd.to_datetime(df[col])
    if datetime_type == 'year':
        df[new_col] = df[col].dt.year
    elif datetime_type == 'month':
        df[new_col] = df[col].dt.month
    elif datetime_type == 'dayofweek':
        df[new_col] = df[col].dt.dayofweek
    elif datetime_type == 'hour':
        df[new_col] = df[col].dt.hour
    else:
        print("wrong datetime type")
    return df

#convert col values dtype: int, float, string, etc
def convert_dtype(df, col: str, new_dtype: str):
    df[col] = df[col].astype(new_dtype)
    return df

#convert dtype in columns
parse_date_cols(df, 'Outcome Date', '_', '_')
parse_date_cols(df, 'Date Of Birth', '_', '_')
convert_dtype(df, 'Days in Shelter', 'int')

#Create month, dayofweek, year columns from intake date
parse_date_cols(df, 'Intake Date', 'Intake_Month', datetime_type='month')
parse_date_cols(df, 'Intake Date', 'Intake_dayofweek', datetime_type='dayofweek')
parse_date_cols(df, 'Intake Date', 'Intake_Year', datetime_type='year')

# Parse 'Outcome Date' for EDA, not for modeling - potential data leakage
parse_date_cols(df, 'Outcome Date', 'Outcome_Month', datetime_type='month')
parse_date_cols(df, 'Outcome Date', 'Outcome_dayofweek', datetime_type='dayofweek')
parse_date_cols(df, 'Outcome Date', 'Outcome_Year', datetime_type='year')
# Out:
# wrong datetime type
# wrong datetime type
#              Name Type                       Breed        Color       Sex  \
# 0             SKY  DOG               GERM SHEPHERD    BLACK/TAN    Female
# 1            COCO  DOG                      BEAGLE     TRICOLOR  Neutered
# 2           SUZIE  DOG           LABRADOR RETR/MIX        BLACK    Spayed
# 3             NaN  DOG           GERM SHEPHERD/MIX     TRICOLOR   Unknown
# 4           FELIX  CAT                 DOMESTIC SH        BLACK  Neutered
# ...           ...  ...                         ...          ...       ...
# 19964       *ONYX  CAT                 DOMESTIC SH        BLACK  Neutered
# 19965         NaN  DOG                CHIHUAHUA SH          TAN    Female
# 19966  TEDDY BEAR  DOG            BICHON FRISE/MIX        CREAM  Neutered
# 19967       TIPPY  CAT                 DOMESTIC SH  BLACK/WHITE    Spayed
# 19968       ROSIE  DOG  CAIRN TERRIER/DACHSHUND WH        BLACK    Spayed
#
#         Size Date Of Birth Impound Number Kennel Number Animal ID Intake Date  \
# 0        MED           NaT     K20-035118          DS69   A395686  2020-01-19
# 1      SMALL    2015-04-06     K17-025093          DS83   A379968  2017-08-30
# 2      LARGE    2011-01-23     K15-012348          DA34   A315553  2015-01-07
# 3        MED           NaT     K20-036188           VET   A398868  2020-07-12
# 4      KITTN    2018-05-12     K18-029084         LOBBY   A374683  2018-07-12
# ...      ...           ...            ...           ...       ...         ...
# 19964  SMALL    2011-02-23     K16-017789          CS04   A333091  2016-02-13
# 19965    TOY           NaT     K15-013157          DS91   A317956  2015-03-14
# 19966  SMALL    2011-06-15     K18-028664          DA20   A374057  2018-06-15
# 19967  SMALL    2009-10-13     K17-025618          CA03   A362428  2017-10-09
# 19968  SMALL    2004-08-08     K14-010178         TRUCK   A309932  2014-08-08
#
#       Outcome Date  Days in Shelter Intake Type    Intake Subtype  \
# 0       2020-01-23                4       STRAY             FIELD
# 1       2017-10-04               35       STRAY             FIELD
# 2       2015-01-24               17       STRAY  OVER THE COUNTER
# 3       2020-07-12                0  CONFISCATE         FLD_CRUEL
# 4       2018-08-04               23       STRAY  OVER THE COUNTER
# ...            ...              ...         ...               ...
# 19964   2016-03-18               34       STRAY  OVER THE COUNTER
# 19965   2015-04-23               40       STRAY  OVER THE COUNTER
# 19966   2018-06-15                0       STRAY             FIELD
# 19967   2017-11-05               27       STRAY             FIELD
# 19968   2014-08-08                0       STRAY             FIELD
#
#           Outcome Type        Outcome Subtype Intake Condition  \
# 0      RETURN TO OWNER  OVER THE COUNTER_CALL          HEALTHY
# 1             TRANSFER             NC AN FRND          UNKNOWN
# 2             ADOPTION               INTERNET          HEALTHY
# 3      RETURN TO OWNER                MEDICAL          UNKNOWN
# 4             ADOPTION                 WALKIN          HEALTHY
# ...                ...                    ...              ...
# 19964         ADOPTION                 WALKIN          HEALTHY
# 19965        EUTHANIZE             AGGRESSIVE  TREATABLE/REHAB
# 19966  RETURN TO OWNER   OVER THE COUNTER_WEB          UNKNOWN
# 19967  RETURN TO OWNER  OVER THE COUNTER_PRVS          UNKNOWN
# 19968  RETURN TO OWNER               FLD_PRVS          HEALTHY
#
#       Outcome Condition Intake Jurisdiction Outcome Jurisdiction  \
# 0               HEALTHY              COUNTY               COUNTY
# 1               HEALTHY          SANTA ROSA        OUT OF COUNTY
# 2               HEALTHY          SANTA ROSA           SANTA ROSA
# 3               HEALTHY          SANTA ROSA                  NaN
# 4               HEALTHY          SANTA ROSA               COUNTY
# ...                 ...                 ...                  ...
# 19964           HEALTHY          SANTA ROSA               COUNTY
# 19965       UNTREATABLE          SANTA ROSA                  NaN
# 19966           HEALTHY          SANTA ROSA           SANTA ROSA
# 19967           HEALTHY          SANTA ROSA               COUNTY
# 19968           HEALTHY          SANTA ROSA                  NaN
#
#        Outcome Zip Code                       Location  Count  Intake_Month  \
# 0               95404.0  95404(38.458384, -122.675588)      1             1
# 1               95758.0  95758(38.424655, -121.438065)      1             8
# 2               95404.0  95404(38.458384, -122.675588)      1             1
# 3                   NaN                            NaN      1             7
# 4               95407.0  95407(38.403734, -122.736775)      1             7
# ...                 ...                            ...    ...           ...
# 19964           95403.0  95403(38.486997, -122.749134)      1             2
# 19965               NaN                            NaN      1             3
# 19966           95403.0  95403(38.486997, -122.749134)      1             6
# 19967           95403.0  95403(38.486997, -122.749134)      1            10
# 19968               NaN                            NaN      1             8
#
#        Intake_dayofweek  Intake_Year  Outcome_Month  Outcome_dayofweek  \
# 0                     6         2020            1.0                3.0
# 1                     2         2017           10.0                2.0
# 2                     2         2015            1.0                5.0
# 3                     6         2020            7.0                6.0
# 4                     3         2018            8.0                5.0
# ...                 ...          ...            ...                ...
# 19964                 5         2016            3.0                4.0
# 19965                 5         2015            4.0                3.0
# 19966                 4         2018            6.0                4.0
# 19967                 0         2017           11.0                6.0
# 19968                 4         2014            8.0                4.0
#
#        Outcome_Year
# 0            2020.0
# 1            2017.0
# 2            2015.0
# 3            2020.0
# 4            2018.0
# ...             ...
# 19964        2016.0
# 19965        2015.0
# 19966        2018.0
# 19967        2017.0
# 19968        2014.0
#
# [19969 rows x 30 columns]

# %%
# Create "Age" column that subtracts the pet's date of birth from the intake date
# choose method: median, mean, or 0 --> to replace NaN's
def create_fill_age_col(df, method='median'):
    df['Age'] = df['Intake Date'] - df['Date Of Birth']
    df['Age'] = df['Age'].dt.days.astype(float)
    
    if method == 'median':
        df['Age'] = df['Age'].fillna(df['Age'].median())
    
    elif method == 'mean':
        df['Age'] = df['Age'].fillna(df['Age'].mean())
    
    elif method == '0':
        df['Age'] = df['Age'].fillna(0)
        
    #convert from age in Days to Years
    df['Age'] = round(df['Age'] / 365, 2)
    
    #drop DoB col
    df = df.drop(columns='Date Of Birth', inplace=True)
        
    return df

create_fill_age_col(df)

# %% [markdown]
# ### Simplify column values for: Sex, Outcome Type, and Size
# - Like the previous classification model, the outcome type is being seperated into "good" (alive) or "bad" (dead) outcomes
#     - Speculations, may need to adjust:
#         - May need to isolate "Adoption" to its own class by creating a "neutral" class that includes: Return to owner (RTOS), and Transfer
#         - Size column may not need to be simplified - it might be useful to have "kittn" and "puppy" as their own class
#         - Sex column shows Male, Female, Neutered, and Spayed -- this MAY play a role in adoption rates, need to speculate
#
# ### To separate animal type (Cat, Dog, Other) and run the model for each? Or all together?
# - Probably will need to try both and see which yields a better accuracy score

# %%
def simplify_col_vals(df, col:str, value:list, replacement:list):
    # spayed --> female, neutered --> male, unknown remains as is
    df[col] = df[col].replace(value, replacement*len(value))

# Simplify 'Sex' column from 5 unique vals into 3 - Male, Female, Unknown
def replace_simplify_group_cols(df):
    
    # Create new column 'Fixed' that shows True if an animal is neutered or spayed
    df['Fixed'] = df['Sex'].apply(lambda x: True if x in ['Neutered', 'Spayed'] else False)
    
    # Create new column 'Has_Name' that shows True if an animal has a name
    df['Has_Name'] = df['Name'].notnull()
    
    # Have 'Sex' column only show male or female
    simplify_col_vals(df, 'Sex', ['Neutered'], ['Male'])
    simplify_col_vals(df, 'Sex', ['Spayed'], ['Female'])

    # Simplify 'Outcome Type' --> "good", "neutral", "bad"
    outcome_adopt = ['ADOPTION']
    outcome_return = ['RETURN TO OWNER', 'RTOS']
    outcome_transfer = ['TRANSFER'] 
    outcome_bad = ['DIED', 'DISPOSAL', 'EUTHANIZE', 'ESCAPED/STOLEN']

    #drop 93 rows with missing 'Outcome Type'
    df = df[df['Outcome Type'].notna()]
    simplify_col_vals(df, 'Outcome Type', outcome_bad, [0])
    simplify_col_vals(df, 'Outcome Type', outcome_transfer, [1])
    simplify_col_vals(df, 'Outcome Type', outcome_return, [2])
    simplify_col_vals(df, 'Outcome Type', outcome_adopt, [3])
    # dtype of this column is object -- might need to change to int later
    
#     #simplify 'Size' column
#     smol = ['KITTN', 'PUPPY', 'TOY']
#     simplify_col_vals(df, 'Size', smol, ['SMALL'])
    
    return df

df = replace_simplify_group_cols(df)

# %%
df
# Out:
#              Name Type                       Breed        Color      Sex  \
# 0             SKY  DOG               GERM SHEPHERD    BLACK/TAN   Female
# 1            COCO  DOG                      BEAGLE     TRICOLOR     Male
# 2           SUZIE  DOG           LABRADOR RETR/MIX        BLACK   Female
# 3             NaN  DOG           GERM SHEPHERD/MIX     TRICOLOR  Unknown
# 4           FELIX  CAT                 DOMESTIC SH        BLACK     Male
# ...           ...  ...                         ...          ...      ...
# 19964       *ONYX  CAT                 DOMESTIC SH        BLACK     Male
# 19965         NaN  DOG                CHIHUAHUA SH          TAN   Female
# 19966  TEDDY BEAR  DOG            BICHON FRISE/MIX        CREAM     Male
# 19967       TIPPY  CAT                 DOMESTIC SH  BLACK/WHITE   Female
# 19968       ROSIE  DOG  CAIRN TERRIER/DACHSHUND WH        BLACK   Female
#
#         Size Impound Number Kennel Number Animal ID Intake Date Outcome Date  \
# 0        MED     K20-035118          DS69   A395686  2020-01-19   2020-01-23
# 1      SMALL     K17-025093          DS83   A379968  2017-08-30   2017-10-04
# 2      LARGE     K15-012348          DA34   A315553  2015-01-07   2015-01-24
# 3        MED     K20-036188           VET   A398868  2020-07-12   2020-07-12
# 4      KITTN     K18-029084         LOBBY   A374683  2018-07-12   2018-08-04
# ...      ...            ...           ...       ...         ...          ...
# 19964  SMALL     K16-017789          CS04   A333091  2016-02-13   2016-03-18
# 19965    TOY     K15-013157          DS91   A317956  2015-03-14   2015-04-23
# 19966  SMALL     K18-028664          DA20   A374057  2018-06-15   2018-06-15
# 19967  SMALL     K17-025618          CA03   A362428  2017-10-09   2017-11-05
# 19968  SMALL     K14-010178         TRUCK   A309932  2014-08-08   2014-08-08
#
#        Days in Shelter Intake Type    Intake Subtype  Outcome Type  \
# 0                    4       STRAY             FIELD             2
# 1                   35       STRAY             FIELD             1
# 2                   17       STRAY  OVER THE COUNTER             3
# 3                    0  CONFISCATE         FLD_CRUEL             2
# 4                   23       STRAY  OVER THE COUNTER             3
# ...                ...         ...               ...           ...
# 19964               34       STRAY  OVER THE COUNTER             3
# 19965               40       STRAY  OVER THE COUNTER             0
# 19966                0       STRAY             FIELD             2
# 19967               27       STRAY             FIELD             2
# 19968                0       STRAY             FIELD             2
#
#              Outcome Subtype Intake Condition Outcome Condition  \
# 0      OVER THE COUNTER_CALL          HEALTHY           HEALTHY
# 1                 NC AN FRND          UNKNOWN           HEALTHY
# 2                   INTERNET          HEALTHY           HEALTHY
# 3                    MEDICAL          UNKNOWN           HEALTHY
# 4                     WALKIN          HEALTHY           HEALTHY
# ...                      ...              ...               ...
# 19964                 WALKIN          HEALTHY           HEALTHY
# 19965             AGGRESSIVE  TREATABLE/REHAB       UNTREATABLE
# 19966   OVER THE COUNTER_WEB          UNKNOWN           HEALTHY
# 19967  OVER THE COUNTER_PRVS          UNKNOWN           HEALTHY
# 19968               FLD_PRVS          HEALTHY           HEALTHY
#
#       Intake Jurisdiction Outcome Jurisdiction  Outcome Zip Code  \
# 0                  COUNTY               COUNTY           95404.0
# 1              SANTA ROSA        OUT OF COUNTY           95758.0
# 2              SANTA ROSA           SANTA ROSA           95404.0
# 3              SANTA ROSA                  NaN               NaN
# 4              SANTA ROSA               COUNTY           95407.0
# ...                   ...                  ...               ...
# 19964          SANTA ROSA               COUNTY           95403.0
# 19965          SANTA ROSA                  NaN               NaN
# 19966          SANTA ROSA           SANTA ROSA           95403.0
# 19967          SANTA ROSA               COUNTY           95403.0
# 19968          SANTA ROSA                  NaN               NaN
#
#                             Location  Count  Intake_Month  Intake_dayofweek  \
# 0      95404(38.458384, -122.675588)      1             1                 6
# 1      95758(38.424655, -121.438065)      1             8                 2
# 2      95404(38.458384, -122.675588)      1             1                 2
# 3                                NaN      1             7                 6
# 4      95407(38.403734, -122.736775)      1             7                 3
# ...                              ...    ...           ...               ...
# 19964  95403(38.486997, -122.749134)      1             2                 5
# 19965                            NaN      1             3                 5
# 19966  95403(38.486997, -122.749134)      1             6                 4
# 19967  95403(38.486997, -122.749134)      1            10                 0
# 19968                            NaN      1             8                 4
#
#        Intake_Year  Outcome_Month  Outcome_dayofweek  Outcome_Year    Age  \
# 0             2020            1.0                3.0        2020.0   1.96
# 1             2017           10.0                2.0        2017.0   2.40
# 2             2015            1.0                5.0        2015.0   3.96
# 3             2020            7.0                6.0        2020.0   1.96
# 4             2018            8.0                5.0        2018.0   0.17
# ...            ...            ...                ...           ...    ...
# 19964         2016            3.0                4.0        2016.0   4.98
# 19965         2015            4.0                3.0        2015.0   1.96
# 19966         2018            6.0                4.0        2018.0   7.01
# 19967         2017           11.0                6.0        2017.0   7.99
# 19968         2014            8.0                4.0        2014.0  10.01
#
#        Fixed  Has_Name
# 0      False      True
# 1       True      True
# 2       True      True
# 3      False     False
# 4       True      True
# ...      ...       ...
# 19964   True      True
# 19965  False     False
# 19966   True      True
# 19967   True      True
# 19968   True      True
#
# [19876 rows x 32 columns]

# %%
def create_subdfs(df):
    
    # Separated by Animal Type
    df_cat = df[df['Type'] == 'CAT']
    df_dog = df[df['Type'] == 'DOG']
    df_other = df[df['Type'] == 'OTHER']

    return df_cat, df_dog, df_other

df_cat, df_dog, df_other = create_subdfs(df)

# %%
df_good['Days in Shelter'].plot(kind='kde', xlim=(0,150), title='Number of Days in Shelter for Adopted Pets')
df_good['Days in Shelter'].describe()
# Out:
# count    6722.000000
# mean        3.430973
# std         9.548820
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max       379.000000
# Name: Days in Shelter, dtype: float64

# %%
df_neut['Days in Shelter'].plot(kind='kde', xlim=(0,150), title='Number of Days in Shelter for Neutral Outcomes')

df_neut['Days in Shelter'].describe()
# Out:
# count    3772.000000
# mean       19.368770
# std        35.303864
# min         0.000000
# 25%         3.000000
# 50%        12.000000
# 75%        24.000000
# max       891.000000
# Name: Days in Shelter, dtype: float64

# %%
df_bad['Days in Shelter'].plot(kind='kde', xlim=(0,150), title='Number of Days in Shelter for Bad Outcomes')

df_bad['Days in Shelter'].describe()
# Out:
# count    3056.000000
# mean       14.925065
# std        28.807072
# min         0.000000
# 25%         0.000000
# 50%         8.000000
# 75%        18.000000
# max       798.000000
# Name: Days in Shelter, dtype: float64

# %% [markdown]
# ### For this model, `Outcome Type` now includes 3 classes: bad, neutral, good
#     - Good(adopted), Neutral(return, transfer), Bad(euthanize, disposal, died, escaped/stolen)
#
# #### Since we'll be predicting "Days in Shelter", the different outcomes will have different rates.
#     - And probably the same for different types of animals: dogs, cats, and other (chicken, rabbit, goats, pigs, etc.)

# %%
df['Outcome Type'].unique()
# 0 is "euthanize", 1 is "transfer", 2 is "return to owner", 3 is "adoption"
# Out:
# array([2, 1, 3, 0])

# %%
def sort_ascending(df, column: str, asc=True):
    df = df.sort_values(column, ascending=asc)
    return df

#sort df by Intake Date so it's in chronological order
sort_ascending(df, 'Intake Date')
# Out:
#                  Name   Type           Breed            Color     Sex   Size  \
# 9485           ATHENA  OTHER       RABBIT SH            BLACK  Female  SMALL
# 10304           ZIGGY    CAT     DOMESTIC SH  ORG TABBY/WHITE  Female  SMALL
# 6320           *ALICE    DOG        PIT BULL       GRAY/WHITE  Female    MED
# 12819            NALA    CAT     DOMESTIC SH           CALICO  Female  SMALL
# 12122           KHLOE    DOG        PIT BULL       BLUE/WHITE  Female    MED
# ...               ...    ...             ...              ...     ...    ...
# 2244              LEO    DOG      POODLE TOY          APRICOT    Male  SMALL
# 2240         RAMBO JR  OTHER           SHEEP      WHITE/BLACK    Male  LARGE
# 2416   COOPER HURTADO    DOG   LABRADOR RETR           YELLOW    Male    MED
# 2458           BAILEY    DOG   SC WHEAT TERR        TAN/WHITE    Male  SMALL
# 2714           JASPER    DOG  ROTTWEILER/MIX      BLACK/BROWN    Male  LARGE
#
#       Impound Number Kennel Number Animal ID Intake Date Outcome Date  \
# 9485      K13-005008           SMA   A295655  2013-08-16   2014-01-04
# 10304     K13-005041      WESTFARM   A295782  2013-08-17   2014-01-07
# 6320      K13-005161          DA38   A296009  2013-08-22   2014-04-14
# 12819     K13-005202         LOBBY   A296108  2013-08-24   2014-03-01
# 12122     K13-005378          DA11   A294143  2013-08-31   2014-04-14
# ...              ...           ...       ...         ...          ...
# 2244      K20-036688         TRUCK   A391341  2020-09-09   2020-09-09
# 2240      K20-036693         TRUCK   A400340  2020-09-09   2020-09-09
# 2416      K20-036700          DS79   A390808  2020-09-10   2020-09-11
# 2458      K20-036706          DS50   A400370  2020-09-10   2020-09-11
# 2714      K20-036695         DQ111   A400346  2020-09-10   2020-09-12
#
#        Days in Shelter      Intake Type    Intake Subtype  Outcome Type  \
# 9485               141            STRAY  OVER THE COUNTER             3
# 10304              143            STRAY  OVER THE COUNTER             3
# 6320               235         TRANSFER          VET_HOSP             0
# 12819              189  OWNER SURRENDER  OVER THE COUNTER             3
# 12122              226            STRAY             FIELD             0
# ...                ...              ...               ...           ...
# 2244                 0            STRAY             FIELD             2
# 2240                 0            STRAY             FIELD             2
# 2416                 1            STRAY             FIELD             2
# 2458                 1            STRAY             PHONE             2
# 2714                 2            STRAY             FIELD             2
#
#              Outcome Subtype Intake Condition Outcome Condition  \
# 9485                INTERNET          HEALTHY           HEALTHY
# 10304               WESTFARM          HEALTHY           HEALTHY
# 6320              BEH SEVERE          HEALTHY       UNTREATABLE
# 12819                 WALKIN  TREATABLE/REHAB           HEALTHY
# 12122             BEH SEVERE          HEALTHY       UNTREATABLE
# ...                      ...              ...               ...
# 2244               FLD_IDTAG          UNKNOWN           PENDING
# 2240                 FLD_NBR          UNKNOWN           HEALTHY
# 2416    OVER THE COUNTER_WEB          UNKNOWN           PENDING
# 2458    OVER THE COUNTER_WEB          UNKNOWN           PENDING
# 2714   OVER THE COUNTER_CALL          UNKNOWN           PENDING
#
#       Intake Jurisdiction Outcome Jurisdiction  Outcome Zip Code  \
# 9485           SANTA ROSA               COUNTY           95472.0
# 10304          SANTA ROSA               COUNTY           95472.0
# 6320               COUNTY                  NaN               NaN
# 12819          SANTA ROSA           SANTA ROSA           95409.0
# 12122              COUNTY           SANTA ROSA           95401.0
# ...                   ...                  ...               ...
# 2244           SANTA ROSA           SANTA ROSA           95403.0
# 2240               COUNTY               COUNTY           95472.0
# 2416               COUNTY               COUNTY           95476.0
# 2458               COUNTY            *PETALUMA           94952.0
# 2714               COUNTY               COUNTY           95446.0
#
#                             Location  Count  Intake_Month  Intake_dayofweek  \
# 9485   95472(38.394388, -122.850998)      1             8                 4
# 10304  95472(38.394388, -122.850998)      1             8                 5
# 6320                             NaN      1             8                 3
# 12819  95409(38.458965, -122.630156)      1             8                 5
# 12122  95401(38.446019, -122.766748)      1             8                 5
# ...                              ...    ...           ...               ...
# 2244   95403(38.486997, -122.749134)      1             9                 2
# 2240   95472(38.394388, -122.850998)      1             9                 2
# 2416   95476(38.280393, -122.464588)      1             9                 3
# 2458   94952(38.236012, -122.730241)      1             9                 3
# 2714   95446(38.510032, -122.996796)      1             9                 3
#
#        Intake_Year  Outcome_Month  Outcome_dayofweek  Outcome_Year    Age  \
# 9485          2013            1.0                5.0        2014.0   3.00
# 10304         2013            1.0                1.0        2014.0   5.98
# 6320          2013            4.0                0.0        2014.0   0.97
# 12819         2013            3.0                5.0        2014.0   6.42
# 12122         2013            4.0                0.0        2014.0   0.89
# ...            ...            ...                ...           ...    ...
# 2244          2020            9.0                2.0        2020.0   3.99
# 2240          2020            9.0                2.0        2020.0   1.96
# 2416          2020            9.0                4.0        2020.0   3.72
# 2458          2020            9.0                4.0        2020.0  13.01
# 2714          2020            9.0                5.0        2020.0   1.96
#
#        Fixed  Has_Name
# 9485    True      True
# 10304   True      True
# 6320    True      True
# 12819   True      True
# 12122   True      True
# ...      ...       ...
# 2244   False      True
# 2240   False      True
# 2416   False      True
# 2458    True      True
# 2714   False      True
#
# [19876 rows x 32 columns]

# %%
df.groupby('Type').count()['Sex'].plot(kind='bar', title='Intake Count by Animal Type')
df.groupby('Type').count()['Sex']
#1556 rows, or 8%, of the data is type "Other".. includes donkey, pig, rabbit, goat, etc.
# Out:
# Type
# CAT       7077
# DOG      11243
# OTHER     1556
# Name: Sex, dtype: int64

# %%
df_good.groupby('Type').count()['Sex'].plot(kind='bar', title='Adoption Count by Animal Type')

# %% [markdown]
# ### How to take care of NaN values?
# - What about "unknown" string values? (e.g. intake condition)
# - Name NaN's shouldn't matter.
# - Date of birth -- how to replace NaNs?
#     - Create an "age" column: outcome date - date of birth

# %%
# A lot of different breeds -- how to handle?

len(df.groupby('Type')['Breed'].unique()['CAT'])
#49 cat breeds

len(df.groupby('Type')['Breed'].unique()['DOG'])
#774 dog breeds

len(df.groupby('Type')['Breed'].unique()['OTHER'])
#120 'other' breeds


# Separate mixed breeds into 2 separate breed columns
def separate_breed(df):
    df['Breed'] = df['Breed'].str.replace('/MIX', '')
    new_val = df['Breed'].str.split('/', n=1, expand=True)
    
    df['Breed_1'] = new_val[0]
    df['Breed_2'] = new_val[1]
    
    df = df.drop(columns='Breed', inplace=True)
    
    return df

separate_breed(df)

# %%
def separate_color(df):
    new_val = df['Color'].str.split('/', n=1, expand=True)
    
    df['Color_1'] = new_val[0]
    df['Color_2'] = new_val[1]
    
    df = df.drop(columns='Color', inplace=True)
    
    return df

separate_color(df)

# %%
# Treatable/Rehab and Treatable/Manageable into a single value -- Treatable

def simplify_intake_condition(df):
    new_val = df['Intake Condition'].str.split('/', n=1, expand=True)
    df['Intake Condition'] = new_val[0]
    
    return df

simplify_intake_condition(df)
# Out:
#              Name Type      Sex   Size Impound Number Kennel Number Animal ID  \
# 0             SKY  DOG   Female    MED     K20-035118          DS69   A395686
# 1            COCO  DOG     Male  SMALL     K17-025093          DS83   A379968
# 2           SUZIE  DOG   Female  LARGE     K15-012348          DA34   A315553
# 3             NaN  DOG  Unknown    MED     K20-036188           VET   A398868
# 4           FELIX  CAT     Male  KITTN     K18-029084         LOBBY   A374683
# ...           ...  ...      ...    ...            ...           ...       ...
# 19964       *ONYX  CAT     Male  SMALL     K16-017789          CS04   A333091
# 19965         NaN  DOG   Female    TOY     K15-013157          DS91   A317956
# 19966  TEDDY BEAR  DOG     Male  SMALL     K18-028664          DA20   A374057
# 19967       TIPPY  CAT   Female  SMALL     K17-025618          CA03   A362428
# 19968       ROSIE  DOG   Female  SMALL     K14-010178         TRUCK   A309932
#
#       Intake Date Outcome Date  Days in Shelter Intake Type    Intake Subtype  \
# 0      2020-01-19   2020-01-23                4       STRAY             FIELD
# 1      2017-08-30   2017-10-04               35       STRAY             FIELD
# 2      2015-01-07   2015-01-24               17       STRAY  OVER THE COUNTER
# 3      2020-07-12   2020-07-12                0  CONFISCATE         FLD_CRUEL
# 4      2018-07-12   2018-08-04               23       STRAY  OVER THE COUNTER
# ...           ...          ...              ...         ...               ...
# 19964  2016-02-13   2016-03-18               34       STRAY  OVER THE COUNTER
# 19965  2015-03-14   2015-04-23               40       STRAY  OVER THE COUNTER
# 19966  2018-06-15   2018-06-15                0       STRAY             FIELD
# 19967  2017-10-09   2017-11-05               27       STRAY             FIELD
# 19968  2014-08-08   2014-08-08                0       STRAY             FIELD
#
#        Outcome Type        Outcome Subtype Intake Condition Outcome Condition  \
# 0                 2  OVER THE COUNTER_CALL          HEALTHY           HEALTHY
# 1                 1             NC AN FRND          UNKNOWN           HEALTHY
# 2                 3               INTERNET          HEALTHY           HEALTHY
# 3                 2                MEDICAL          UNKNOWN           HEALTHY
# 4                 3                 WALKIN          HEALTHY           HEALTHY
# ...             ...                    ...              ...               ...
# 19964             3                 WALKIN          HEALTHY           HEALTHY
# 19965             0             AGGRESSIVE        TREATABLE       UNTREATABLE
# 19966             2   OVER THE COUNTER_WEB          UNKNOWN           HEALTHY
# 19967             2  OVER THE COUNTER_PRVS          UNKNOWN           HEALTHY
# 19968             2               FLD_PRVS          HEALTHY           HEALTHY
#
#       Intake Jurisdiction Outcome Jurisdiction  Outcome Zip Code  \
# 0                  COUNTY               COUNTY           95404.0
# 1              SANTA ROSA        OUT OF COUNTY           95758.0
# 2              SANTA ROSA           SANTA ROSA           95404.0
# 3              SANTA ROSA                  NaN               NaN
# 4              SANTA ROSA               COUNTY           95407.0
# ...                   ...                  ...               ...
# 19964          SANTA ROSA               COUNTY           95403.0
# 19965          SANTA ROSA                  NaN               NaN
# 19966          SANTA ROSA           SANTA ROSA           95403.0
# 19967          SANTA ROSA               COUNTY           95403.0
# 19968          SANTA ROSA                  NaN               NaN
#
#                             Location  Count  Intake_Month  Intake_dayofweek  \
# 0      95404(38.458384, -122.675588)      1             1                 6
# 1      95758(38.424655, -121.438065)      1             8                 2
# 2      95404(38.458384, -122.675588)      1             1                 2
# 3                                NaN      1             7                 6
# 4      95407(38.403734, -122.736775)      1             7                 3
# ...                              ...    ...           ...               ...
# 19964  95403(38.486997, -122.749134)      1             2                 5
# 19965                            NaN      1             3                 5
# 19966  95403(38.486997, -122.749134)      1             6                 4
# 19967  95403(38.486997, -122.749134)      1            10                 0
# 19968                            NaN      1             8                 4
#
#        Intake_Year  Outcome_Month  Outcome_dayofweek  Outcome_Year    Age  \
# 0             2020            1.0                3.0        2020.0   1.96
# 1             2017           10.0                2.0        2017.0   2.40
# 2             2015            1.0                5.0        2015.0   3.96
# 3             2020            7.0                6.0        2020.0   1.96
# 4             2018            8.0                5.0        2018.0   0.17
# ...            ...            ...                ...           ...    ...
# 19964         2016            3.0                4.0        2016.0   4.98
# 19965         2015            4.0                3.0        2015.0   1.96
# 19966         2018            6.0                4.0        2018.0   7.01
# 19967         2017           11.0                6.0        2017.0   7.99
# 19968         2014            8.0                4.0        2014.0  10.01
#
#        Fixed  Has_Name        Breed_1       Breed_2   Color_1 Color_2
# 0      False      True  GERM SHEPHERD          None     BLACK     TAN
# 1       True      True         BEAGLE          None  TRICOLOR    None
# 2       True      True  LABRADOR RETR          None     BLACK    None
# 3      False     False  GERM SHEPHERD          None  TRICOLOR    None
# 4       True      True    DOMESTIC SH          None     BLACK    None
# ...      ...       ...            ...           ...       ...     ...
# 19964   True      True    DOMESTIC SH          None     BLACK    None
# 19965  False     False   CHIHUAHUA SH          None       TAN    None
# 19966   True      True   BICHON FRISE          None     CREAM    None
# 19967   True      True    DOMESTIC SH          None     BLACK   WHITE
# 19968   True      True  CAIRN TERRIER  DACHSHUND WH     BLACK    None
#
# [19876 rows x 34 columns]

# %% [markdown]
# ## Create dummies for categorial features

# %%
def dummify_categ_cols(df):
    
    need_dummies = ['Type', 'Sex', 'Size', 'Intake Condition', 
                'Breed_1', 'Breed_2', 'Color_1', 'Color_2']
    
    # Take care of NaNs before creating dummies
    df['Size'].fillna('Unknown', inplace=True)
    
    for col in need_dummies:
        
        dummies = pd.get_dummies(df[col], prefix=col)
        df = pd.concat([df, dummies], axis=1)
    
    # cols in need_dummies will be dropped in the drop_cols function
    
    return df

df = dummify_categ_cols(df)

# %% [markdown]
# ## Create sub DF's for each Outcome Type

# %%
df_good, df_neut, df_bad = create_subdfs(df, feature_split='Outcome Type')
df_cat, df_dog, df_other = create_subdfs(df, feature_split='Type')

# %% [markdown]
# ## Drop columns that are irrelevant and/or `Outcome` related
# - Outcome columns will lead to data leakage as they're explanatory columns
# - Simplify 'Sex' column into Male, Female, Unknown (currently we have Spayed and Neutered as well)

# %%
#We have a new dependent variable -- 'Days in Shelter', combine with drop_col function from part 1 and specify model type

def drop_cols(df, model: str):
    '''
    Input: dataframe, model type = 'clf' or 'reg'
    'clf' model will drop 'Outcome Type' and leave 'Days in Shelter' to be the dependent variable
    'reg' model will drop 'Days in Shelter' and leave 'Outcome Type' to be the dependent variable
    
    Output:
    dataframe with dropped columns
    '''
    
    if model == 'reg':
        
        # Remove 'Outcome Type', keep 'Days in Shelter'
        drop_cols = ['Name', 'Impound Number', 'Kennel Number', 'Outcome Subtype', 
                     'Intake Jurisdiction', 'Outcome Jurisdiction', 'Outcome Jurisdiction', 
                     'Location', 'Count', 'Animal ID', 'Outcome_Year',
                     'Intake Type', 'Intake Subtype', 'Outcome Condition', 
                     'Outcome Date', 'Outcome Zip Code', 'Outcome_Month', 'Outcome_dayofweek',
                    'Outcome Type', 'Type', 'Sex', 'Size', 'Intake Condition', 
                    'Breed_1', 'Breed_2', 'Color_1', 'Color_2'] 
     
        df = df.drop(columns=drop_cols)

        return df
    
    elif model == 'clf':
        
        # Remove 'Days in Shelter', keep 'Outcome Type'
        drop_cols = ['Name', 'Impound Number', 'Kennel Number', 'Outcome Subtype', 
                     'Intake Jurisdiction', 'Outcome Jurisdiction', 'Outcome Jurisdiction', 
                     'Location', 'Count', 'Animal ID', 'Outcome_Year',
                     'Intake Type', 'Intake Subtype', 'Outcome Condition', 
                     'Outcome Date', 'Outcome Zip Code', 'Outcome_Month', 'Outcome_dayofweek',
                    'Days in Shelter', 'Type', 'Sex', 'Size', 'Intake Condition', 
                    'Breed_1', 'Breed_2', 'Color_1', 'Color_2'] 
        
        df = df.drop(columns=drop_cols)

        return df
    
    else:
        print("Enter Model: 'clf' or 'reg'.")

#create dfs for regression model
df_reg = drop_cols(df, 'reg')        
df_cat_reg = drop_cols(df_cat, 'reg')
df_dog_reg = drop_cols(df_dog, 'reg')
df_other_reg = drop_cols(df_other, 'reg')

#create dfs for classification model (part 1)
df_clf = drop_cols(df, 'clf')
df_cat_clf = drop_cols(df_cat, 'clf')
df_dog_clf = drop_cols(df_cat, 'clf')
df_other_clf = drop_cols(df_cat, 'clf')

# %% [markdown]
# ## Build a Random Forest Regressor
# - Calculate the Mean Absolute Error (MAE) and compare with the baseline MAE.
#     - Baseline MAE = y_test - mean(y_test)

# %%
def run_rf_reg(df, n_estimators=50, criterion='mae'):
    
    # Set up train and test sets
    y = df['Days in Shelter']
    X = df.drop(columns=['Days in Shelter', 'Intake Date'])
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=15)
    
    # Print baseline MAE score
    baseline_errors = abs(y_test - y_test.mean())
    print('Average baseline error: ', round(np.mean(baseline_errors), 2))
    
    # Set up RF Regressor and run
    regr = RandomForestRegressor(n_estimators=n_estimators, criterion=criterion,
                            n_jobs=-1, verbose=2, random_state=13)
    # Train and predict
    regr.fit(X_train, y_train)
    pred = regr.predict(X_test)
    
    # Print metrics
    print('Mean Absolute Error (MAE):', mean_absolute_error(y_test, pred))
    print('Mean Squared Error (MSE):', mean_squared_error(y_test, pred))
    print('Root Mean Squared Error (RMSE):', np.sqrt(mean_squared_error(y_test, pred)))
    
    # Plot feature importances
    feat_scores = pd.DataFrame({'Fraction of Samples Affected' : regr.feature_importances_},
                           index=X.columns)
    feat_scores = feat_scores.sort_values(by='Fraction of Samples Affected', ascending=False)
    feat_scores[:30].plot(kind='barh', figsize=(10,10))
    plt.show()

# %%
# Everything combined - animal type, outcome type

# run_rf_reg(df)

# Baseline MSE: 16.33
# RF MAE: 12.14 --- 23% decrease

# Top 5 features: Age, Intake month/year/day of week, Fixed, Intake Condition, Has name

# %% [markdown]
# ## How will the model perform if we separate the data into:
# - Different Outcome Types
#     - Good (adoption), neutral (transfer, return), or bad (euthanize, dead)
# - Different Animal Types
#     - Cats, Dogs, or Other (pigs, birds, donkeys, etc

# %%
# Predict 'Days in Shelter' given that the outcome is adoption

# run_rf_reg(df_good)

# Baseline MAE: 21.23
# RF MAE: 16.68 --- 21.4% decrease

# Top 5 features: Age, Intake date, Intake condition, Pitbull, Border Collie, Black

# %%
# Predict 'Days in Shelter' given that the outcome is either Transfer or Return to Owner

# run_rf_reg(df_neut)

# Baseline MAE: 10.76
# RF MAE: 8.48 -- 21.1% decrease

# Top 5 features: Age, Intake date, Type Other, Fixed, Dachshund

# %%
# Predict 'Days in Shelter' given that the outcome is Euthanize, Dead, or Escaped

# run_rf_reg(df_bad)

# Baseline MAE: 13.93
# RF MAE: 8.50 -- 40.0% decrease

# Top 5 features: Type Dog, Age, Intake Date, Has Name, Red

# %%
# Predict 'Days in Shelter' for Cats only

# run_rf_reg(df_cat)

# Baseline MAE: 15.06
# RF MAE: 8.65 -- 42.6% decrease
# Top 5 features: Age, Has Name, Intake Date, Fixed, Intake Condition

# %%
# Predict 'Days in Shelter' for Dogs only

# run_rf_reg(df_dog)

# Baseline MAE: 16.29
# RF MAE: 14.39 -- 11.7% decrease

# Top 5 features: Age, Intake date, Intake condition, fixed, white, tan

# %%
# Predict 'Days in Shelter' for 'other' animals - pigs, goats, birds, sheep, etc

# run_rf_reg(df_other)

# Baseline MAE: 20.97
# RF MAE: 9.91 -- 52.7% decrease

# Top 5 features: Intake date, age, sex, intake condition, fixed, Koi

# %%
# Save datasets that can be plugged into models

# df.to_csv('data_cleaned.csv')
# df_good.to_csv('data_cleaned_adopted.csv')
# df_neut.to_csv('data_cleaned_transfer_return.csv')
# df_bad.to_csv('data_cleaned_euthanize_dead.csv')
# df_cat.to_csv('cats_data_cleaned.csv')
# df_dog.to_csv('dogs_data_cleaned.csv')
# df_other.to_csv('other_animals_data_cleaned.csv')

# %%
df_reg.to_csv('reg_data_cleaned.csv')
df_cat_reg.to_csv('reg_cat_data.csv')
df_dog_reg.to_csv('reg_dog_data.csv')
df_other_reg.to_csv('reg_other_data.csv')

df_clf.to_csv('clf_data_cleaned.csv')
df_cat_clf.to_csv('clf_cat_data.csv')
df_dog_clf.to_csv('clf_dog_data.csv')
df_other_clf.to_csv('clf_other_data.csv')

# %% [markdown]
# ## Need to try gridsearchCV to find optimal parameters.
# > Try Gradient Boosting and XG Boost

# %%
# AFTER classification, look into time series
time_series = df['Intake Date'].sort_values()
